# %% [markdown]
# ## Testing

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.neighbors import NearestNeighbors
import numpy as np
from numpy.linalg import norm
import pickle
import matplotlib.pyplot as plt

# %%
# Load the pre-trained model
base_model = tf.keras.applications.ResNet50(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalMaxPooling2D()
])

# Load the pre-trained features and filenames
feature_list = pickle.load(open('embeddings.pkl', 'rb'))
filenames = pickle.load(open('filenames.pkl', 'rb'))

# Normalize the feature list
normalized_feature_list = [features / norm(features) for features in feature_list]

# %%
# Test with an example image
display_similar_images('test_shirt.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# [[11976 11859 25692 12059 11847 25787]]

# %%
# Test with an example image
display_similar_images('1619.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# [[20661 20662 20658 20669 20659 20663]]

# %%
# Test with an example image
display_similar_images('test_jersey.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# [[35293 34988 35011 34139 31183 30017]]

# %%
# Test with an example image
display_similar_images('test_pant.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# [[28246 28248 27927 27946 28751 28108]]

# %%
# Test with an example image
display_similar_images('1832.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# [[22343 24035 24019 23827  4319 22781]]

# %%
# Test with an example image
display_similar_images('tshirt.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# [[31120 17901 19142 33913 31575 33883]]

# %%
# Test with an example image
display_similar_images('1762.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# [[29987 29175 34940 34249 30037 30337]]

# %%
# Test with an example image
display_similar_images('54725.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# [[14555 14556 14532 26252 14550 14531]]

# %%
# Test with an example image
display_similar_images('test_socks.jpeg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# [[21456 21257 21802 21266 21801 21797]]
